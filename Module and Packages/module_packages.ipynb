# %% [markdown]
# # Modules and Packages

# %%
def addition(num1,num2):
    return num1+num2

# %%
addition(2,3)
# Out:
# 5

# %% [markdown]
# ## I want to use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
# How the complex the logic of a square root function is going to be

# %% [markdown]
# ## Module
# #### A module in python is simply a file containg python code (function,classes or variables) that can be imported and used in other programs

# %% [markdown]
# # Numpy-->
# ### Numpy module is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can aplly the operation with our array a bit more faster as compared to those of the list

# %% [markdown]
# ### ---> we cam do it in Numpy just because Numpy is having the collection of functions and attributes which can help us to work effeciently with the array

# %% [markdown]
# # Pandas
# ### Pandas we can use when we are going to work with the dataset for cleaning, pre-processing, EDA, analysis with plotting as well

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(18)
# Out:
# 4.242640687119285

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
'''
A module:

1. A module helps in code organization
2. It promotes reusability
3. It keeps the code clean and manageable
'''
# Out:
# '\nA module:\n\n1. A module helps in code organization\n2. It promotes reusability\n3. It keeps the code clean and manageable\n'

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
print(factorial(5))
# Out:
# 120

# %%
import numpy

# %%
list_items=[[1,2,3,4,5]]
numpy_array=numpy.array(list_items)

type(numpy_array)
print(numpy_array)
# Out:
# [[1 2 3 4 5]]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %%
# !pip install seaborn

# %% [markdown]
# ## I am trying to create my own library or module and in this library i want the functions and the attribute to be created on my own

# %%
# _init_.py is a file that has to be their inside the package forlder and this _init_.py file helps us out in defining 
# our packages and initializing their namespaces

# %%
# _init_.py file can remain empty and its completely fine but this file has to be their when we will be creating 
# our new packages into the package folder

# %%
from package_folder.mathematics import addition, subtraction

# %%
addition(2,4)
# Out:
# 6

# %%
from package_folder.mathematics import *

# %%
division(4,0)
# Out:
# Division not possible

# %%
division(4,3)
# Out:
# 1.3333333333333333
