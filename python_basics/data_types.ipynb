# %% [markdown]
# # Data Types

# %% [markdown]
# ## Data types are classificaton of the data that tells the compiler or the interpreter that what kind of values we can store into a variable and how much amount of memory will be consumed to store the data and the operation it can perform

# %%
age=int(input("Enter the age:"))

# %%
age
# Out:
# '20'

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age2=30

# %%
age2
# Out:
# 30

# %%
print(age+age2)
# Out:
# 50

# %% [markdown]
# # Different types of data types
# ## int
# ## str
# ## float
# ## bool
