# %% [markdown]
# ## Keywords

# %% [markdown]
# ### Keywords are the reserved words which cant be used as our variable as they having a reserved meaning already in python

# %% [markdown]
# ## Keywords are
# ### List
# ### set
