# %% [markdown]
# ## What is Python Language?

# %% [markdown]
# ## Python is a Type of programming language which we can use for communicating which we can use for communicating with computers or technology

# %% [markdown]
# ## Syntax for Python Language

# %% [markdown]
# ### Syntax refers to the set of rules that defines the combination of symbols that are considered to be correctly structured programs in a language

# %% [markdown]
# ## Semantics of Python Language

# %% [markdown]
# ### Semantics of python language refers to the meaning or interpretation of symbols, characters and commands in a language. It is about what the code is supposed to do when it runs.

# %% [markdown]
# ## Python syntax rules :-
# ### 1. Python is case sensitive

# %%
name = "Daksh"
Name = "Daksh"
name == Name
# Out:
# True

# %%
name = "Daksh"
Name = "daksh"
name == Name
# Out:
# False

# %% [markdown]
# ## Identation in Python
#
# ### In other programming language, we use {} for grouping of statements
# ### In python, we use Identation for proper grouping of statements as the proper arrangement of statements with proper spacing in the statements within a block.

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote")

# %%
1+2+3+4+5+6
# Out:
# 21

# %%
1+2+3+4+5+\
6+7
# Out:
# 28

# %% [markdown]
# ### Line continuation --> Wr can use Backslash for continuing the statement on the next line

# %% [markdown]
# ### Multiple Statements in a single line in Python

# %%
a=5 b=6
# Out:
#   Cell In[5], line 1
#     a=5 b=6
#         ^
# SyntaxError: invalid syntax

# %%
a=5; b=6; c=7
