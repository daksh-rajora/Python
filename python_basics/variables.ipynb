# %% [markdown]
# # Variables

# %% [markdown]
# ### Variables as per its name, data can vary that we are going to store into it and once we have declared a variable we can vary the value stored in it

# %%
age = 20
Name = "Daksh"
Height = 5.4
is_true = True

# %%
age
# Out:
# 20

# %% [markdown]
# # print()

# %% [markdown]
# ## print() --> print function is being used to represent the value that we are going to pass inside it|

# %%
print(age)
# Out:
# 20

# %%
print("Name is: ", Name)
# Out:
# Name is:  Daksh

# %% [markdown]
# # Comment
# ## Comment is the statement in a program that we dont want the interpreter to execute
# ## interpreter--> executes the code line by line in python language
# ## compiler--> executes the code completely

# %%
# Hello i am explaing how to write comments

# %% [markdown]
# ## Variable Naming Convention

# %%
'''Variable names must be Descriptive:
   Age=20
    Name="Daksh
    "'''
# Out:
# 'Variable names must be Descriptive:\n   Age=20\n    Name="Daksh\n    "'

# %%
# building a simple calculator

value_1=int(input("Enter your first value: "))
value_2=int(input("Enter your second value: "))
print("The addition for the values is: ", value_1+value_2)
print("The subtraction for the values is: ", value_1-value_2)
print("The product for the values is : ", value_1*value_2)
print("The division for the values is: ", value_1/value_2)
