# %% [markdown]
# # Operators

# %% [markdown]
# ## Operators helps in applying operation on the given operands

# %% [markdown]
# ## Types of Operators:
# 1.Arithmetic Operators
#
# Addition (+)
# Substraction(-)
# Product or Multiplication(*)
# Divsion (/)
# Modulus (%)
# Floor (//)
# Exponent (a**b)
#
# 2. Comparison Operators
#
# Greater than (>)
# Less than(<)
# Greater than or equal to (>=)
# Less than or equal to(<=)
# Equality Check(==)
# not equal to (!=)
#
# 3. Logical Operators
#
# and--> whether if both conditions are true or not
# or--> whether if any of the operation is true or not
# not--> negation or to inverse the result of the given operation

# %% [markdown]
# ## Modulus Operator (%)
# ### Modulus Operator will be helping us out with getting the idea about the remainder that will ve left after dividing the first value with the second value
