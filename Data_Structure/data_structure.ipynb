# %% [markdown]
# # Data Structure in Python
#
# ### Data Structure in Python are being used for storing the data in structrued format so that we can access the data and along with that we can perform all of the operations with these data structures that we can perform in the case of the databases as well likr curd(create,read,update,delete) operations

# %% [markdown]
# ## Types of Data structures
# ### 1.List
# ### 2.Tuple
# ### 3.Set
# ### 4.Dictionary

# %% [markdown]
# ### The different types of the data structure differs on this basis that in which specific format we want to store our data
